# %% [markdown]
# <a href="https://colab.research.google.com/github/edgar155/unidad3/blob/main/actividad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 3
#
#  Concepotos basicos de la libreria MATPLOTLIB es una libreria de trasado de graficos de bajo nivel en python que sirve como una herramienta de vizualizacion. matplotlib es de codigo abierto y podemos utilizarlo libremente principalmente en python con algunos segmentos escritos en instalacion de matplotlib.
#
#  si tienes python y pip ya instalado en tu sistema , instala matplotlib usando el siguiente comando  pip install matplotlib
#  desde la linea de comandos importar matplotlib una vez instaladd matplotlib importalo en tus aplicaciones agregado en el modulo import,ejemplo
#  import matplotlib, matplotlib pyplot la mayoria de las herramientas de matplotlib se encuentran dentro del submodulo pyplot y normalmente se importan bajo el alias ph: import matplotlib.pyplo0t as plt ahora el paquete pyplot puede denominarse plt
